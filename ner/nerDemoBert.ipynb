# %%
import spacy
from ner.KBBert.SweBertNer import SweBertNer
import transformers
from transformers import pipeline
from spacy import displacy

nlp = spacy.load('../Models/SwedishModel')
from spacy.pipeline import EntityRuler


nlpTrans = pipeline('ner', model='KB/bert-base-swedish-cased-neriob', tokenizer='KB/bert-base-swedish-cased-neriob')

# %%
nlp.remove_pipe('ner')

trans = SweBertNer(nlpTrans, nlp)
nlp.add_pipe(trans)

"""test_ruler = EntityRuler(nlp,overwrite_ents=True).from_disk('patterns.jsonl')
nlp.add_pipe(test_ruler)"""
# Out:
# "test_ruler = EntityRuler(nlp,overwrite_ents=True).from_disk('patterns.jsonl')\nnlp.add_pipe(test_ruler)"

# %%
sweCorp = ''
with open('ep-06-10-12-003-sv.txt') as f:
    for index, line in enumerate(f):
        sweCorp = sweCorp + line

# %%
doc = nlp(sweCorp)
# Out:
# 2
# 3
# 4
# 21
# 22
# 35
# 36
# 41
# 98
# 99
# 100
# 143
# 162
# 163
# 165
# 166
# 167
# 196
# 202
# 203
# 264
# 280
# 274
# 275
# 277
# 264
# 280
# 287
# 303
# 318
# 332
# 373
# 425
# 471
# 472
# 473
# 474
# 499
# 500
# 547
# 550
# 573
# 574
# 606
# 611
# 612
# 632
# 728
# 729
# 770
# 795
# 879
# 938
# 1052
# 1254
# 1255
# 1318
# 1319
# 1459
# 1460
# 1469
# 1511
# 1524
# 1533
# 1534
# 1535
# 1554
# 1657
# 1658
# 1659
# 1723
# 1745
# 1746
# 1747
# 1748
# 1797
# 1854
# 1859
# 1860
# 1952
# 1961
# 1962
# 2149
# 2150
# 2164
# 2193
# 2194
# 2401
# 2402
# 2429
# 2430
# 2509
# 2510
# 2511
# 2526
# 2527
# 2528
# 2544
# 2545
# 2562
# 2567
# 2568
# 2596
# 2597
# 2732
# 2746
# 2747
# 2748
# 2750
# 2751
# 2753
# 2754
# 2762
# 2853
# 2854
# 2855
# 2874
# 2883
# 2884
# 2885
# 2886
# 2898
# 2899
# 2900
# 2906
# 2926
# 2927
# 2928
# 2929
# 2930
# 2970
# 2980
# 2981
# 2982
# 3012
# 3119
# 3120
# 3121
# 3132
# 3133
# 3154
# 3155
# 3187
# 3288
# 3289
# 3290
# 3291
# 3298
# 3299
# 3300
# 3301
# 3352
# ...

# %%
print(doc[84].text + ' ' + doc[85].text + ' ' + doc[86].text + ' ' + doc[87].text)
# Out:
# Lilla Jordberga . Första

# %%
displacy.render(doc, 'ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jordberga gods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MNS</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jordberga gods
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MNS</span>
# </mark>
# ,
# ...
