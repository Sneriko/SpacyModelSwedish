# %%
from allennlp.predictors import sentence_tagger
from allennlp.models.archival import load_archive
import allennlp_models.ner.crf_tagger

# %%
predictor = sentence_tagger.SentenceTaggerPredictor.from_path('model.tar.gz')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-10d8e582c9df> in <module>
# ----> 1 predictor = sentence_tagger.SentenceTaggerPredictor.from_path('model.tar.gz')
#       2
#       3
#       4
#
# ~/PycharmProjects/SpacySwedishModel/allennlp/allennlp/predictors/predictor.py in from_path(cls, archive_path, predictor_name, cuda_device, dataset_reader_to_load, frozen)
#     254         """
#     255         return Predictor.from_archive(
# --> 256             load_archive(archive_path, cuda_device=cuda_device),
#     257             predictor_name,
#     258             dataset_reader_to_load=dataset_reader_to_load,
#
# ~/PycharmProjects/SpacySwedishModel/allennlp/allennlp/models/archival.py in load_archive(archive_file, cuda_device, opt_level, overrides, weights_file)
#     195         serialization_dir=serialization_dir,
# ...

# %%
strings = []
sents = []
strings.append('Jag dansar naken på Sergels torg.')
strings.append('Ibland jobbar jag på ericsson eller Volvo med diverse grejer.')
for s in strings:
    sents.append(predictor.predict(s))

# %%
a = predictor.predict('Hej jag heter Erik Lenas och jag jobbar på Google. Riksarkivet hanterar Sveriges arkivmaterial från 1300-talet och framåt.')
