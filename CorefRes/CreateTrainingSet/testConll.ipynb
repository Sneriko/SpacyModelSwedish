# %%
from neuralcoref.train import conllparser as parser

# %%
a = parser.load_file('conll/ep_00_01_17.v4_gold_conll', debug=True)
# Out:
# line 0 cols: ['#begin', 'document', '(ep-00-01-17);', 'part', '0']
# New doc
# New doc ep-00-01-17 0 ep
# line 1 cols: []
# line 2 cols: ['ep-00-01-17', '0', '0', 'Återupptagande', 'PC|PRS|UTR+NEU|SIN+PLU|IND+DEF|NOM', '-', '-', '-', '-', '-', '-']
# Inside utterance
# speaker -
# line 3 cols: ['ep-00-01-17', '0', '1', 'av', 'PP', '-', '-', '-', '-', '-', '-']
# Inside utterance
# line 4 cols: ['ep-00-01-17', '0', '2', 'sessionen', 'NN|UTR|SIN|DEF|NOM', '-', '-', '-', '-', '-', '-']
# Inside utterance
# line 5 cols: []
# End of utterance
# line 6 cols: ['ep-00-01-17', '0', '0', 'Jag', 'PN|UTR|SIN|DEF|SUB', '-', '-', '-', '-', 'Talmannen', '-', '-']
# Inside utterance
# speaker Talmannen
# line 7 cols: ['ep-00-01-17', '0', '1', 'förklarar', 'VB|PRS|AKT', '-', '-', '-', '-', 'Talmannen', '-', '-']
# Inside utterance
# line 8 cols: ['ep-00-01-17', '0', '2', 'Europaparlamentets', 'NN|NEU|SIN|DEF|GEN', '-', '-', '-', '-', 'Talmannen', '-', '-']
# Inside utterance
# ...
