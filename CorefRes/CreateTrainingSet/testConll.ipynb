# %%
from neuralcoref.train import conllparser as parser

# %%
a = parser.load_file('conll/ep-09-03-11-018.v4_gold_conll', debug=True)
# Out:
# line 0 cols: ['#begin', 'document', '(ep-09-03-11-018);', 'part', '0']
# New doc
# New doc ep-09-03-11-018 0 ep
# line 1 cols: []
# line 2 cols: ['ep-09-03-11-018', '0', '0', 'Genomförandet', 'NN|NEU|SIN|DEF|NOM', '-', '-', '-', '-', '-', '-']
# Inside utterance
# speaker -
# line 3 cols: ['ep-09-03-11-018', '0', '1', 'av', 'PP', '-', '-', '-', '-', '-', '-']
# Inside utterance
# line 4 cols: ['ep-09-03-11-018', '0', '2', 'det', 'DT|NEU|SIN|DEF', '-', '-', '-', '-', '-', '-']
# Inside utterance
# line 5 cols: ['ep-09-03-11-018', '0', '3', 'gemensamma', 'JJ|POS|UTR+NEU|SIN|DEF|NOM', '-', '-', '-', '-', '-', '-']
# Inside utterance
# line 6 cols: ['ep-09-03-11-018', '0', '4', 'eurobetalningsområdet', 'NN|NEU|SIN|DEF|NOM', '-', '-', '-', '-', '-', '(1)']
# Inside utterance
# coref_expr ['(1)']
# coref tok (1)
# New coref 1
# i 0
# End coref 1
# line 7 cols: ['ep-09-03-11-018', '0', '5', '(', 'PAD', '-', '-', '-', '-', '-', '-']
# Inside utterance
# ...
